# %% [markdown]
# <a href="https://colab.research.google.com/github/Trymore747/Mining-matplot-lib/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = "Queen, Zama, Beverly, Kitso"
print(names)
g = "hello"
print(g)
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]
plt.plot(x, y)
plt.title('Simple Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()
m = "my name is Paul Heiman"
print(m)
# Out:
# Queen, Zama, Beverly, Kitso
# hello
# my name is Paul Heiman
